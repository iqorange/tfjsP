# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.random.uniform(-1, 3, size=100)
X = x.reshape(-1, 1)

# %%
y = 1.3 * x**2 + x + 2 + np.random.normal(0, 1, size=100)

# %%
plt.scatter(x, y)
plt.show()

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(X, y)
# Out:
# LinearRegression()

# %%
y_predict = lin_reg.predict(X)

# %%
plt.scatter(x, y)
plt.plot(x, y_predict, color='r')
plt.show()

# %%
(X**2).shape
# Out:
# (100, 1)

# %%
X2 = np.hstack([X, X**2])
X2.shape
# Out:
# (100, 2)

# %%
lin_reg2 =LinearRegression()
lin_reg2.fit(X2, y)
y_predict2 = lin_reg2.predict(X2)

# %%
plt.scatter(x, y)
plt.plot(np.sort(x), y_predict2[np.argsort(x)], color='r')
plt.show()

# %%
lin_reg2.coef_
# Out:
# array([0.97039976, 1.37304675])

# %%
lin_reg2.intercept_
# Out:
# 1.7023760543289441
